# %% [markdown]
# # Music Data Preparation

# %%
import pandas as pd

# %%
last_fm_listening_hist = pd.read_csv('data/lastfm-dataset-1K/lastfm_uniq_songs_ge9_wout_c_clean_wout_quotes.csv', sep=';')
last_fm_listening_hist.shape
# Out:
# (313324, 3)

# %%
last_fm_listening_hist.columns = ['artist_name_lastfm', 'tra_id', 'title_lastfm']
last_fm_listening_hist
# Out:
#                       artist_name_lastfm  \
# 0                            ???? (????)
# 1                                    メリー
# 2                                    แดน
# 3                             ติ๊ก ชีโร่
# 4                             จ๊อบ บรรจบ
# 5                             ติ๊ก ชิโร่
# 6                             ติ๊ก ชีโร่
# 7                             ติ๊ก ชิโร่
# 8                            ไอซ์ ศรัณยู
# 9                                โฟร์-มด
# 10                               โฟร์-มด
# 11                                  그대지금
# 12                                 ไมโคร
# 13                                 Ｇｈｏｓｔ
# 14                                 ナイトメア
# 15                                 ดาจิม
# 16                                 スガシカオ
# 17                          เบิร์ด ธงไชย
# 18                          เบิร์ด ธงไชย
# 19                               ヤエル・ナイム
# 20                          マキシマム・ザ・ホルモン
# 21                       クリスタル・ケイ，ケミストリー
# ...

# %%
msd_genre = pd.read_csv('data/msd_genre_dataset.csv')
msd_genre.shape
# Out:
# (59600, 34)

# %%
msd_genre
# Out:
#                       genre            track_id              artist_name  \
# 0      classic pop and rock  TRFCOOU128F427AEC0         Blue Oyster Cult
# 1      classic pop and rock  TRNJTPB128F427AE9F         Blue Oyster Cult
# 2      classic pop and rock  TRLFJHA128F427AEEA         Blue Oyster Cult
# 3      classic pop and rock  TRCQZAG128F427DB97         Blue Oyster Cult
# 4      classic pop and rock  TRNXMNM128F427DB8C         Blue Oyster Cult
# 5      classic pop and rock  TRSIZRN128F427DB95         Blue Oyster Cult
# 6      classic pop and rock  TRDYTEO128F427DB90         Blue Oyster Cult
# 7      classic pop and rock  TRKSICM128F427DB8B         Blue Oyster Cult
# 8      classic pop and rock  TRCJRAM128F934658C         Blue Oyster Cult
# 9      classic pop and rock  TRIERYM128F934657C         Blue Oyster Cult
# 10     classic pop and rock  TRUMVIV128F934656F         Blue Oyster Cult
# 11     classic pop and rock  TRZXOTE128F933D967         Blue Oyster Cult
# ...

# %%
last_fm_with_msd = pd.merge(last_fm_listening_hist, msd_genre,  how='inner', left_on=['artist_name_lastfm', 'title_lastfm'], right_on = ['artist_name','title'])
last_fm_with_msd.shape
# Out:
# (6568, 37)

# %%
last_fm_with_msd
# Out:
#      artist_name_lastfm                                tra_id  \
# 0      Abigail Washburn  238d51be-5828-420a-849e-e54aff4a5ae7
# 1      Abigail Washburn  6f878f9c-d46e-47c0-8ed5-621e479aee67
# 2      Abigail Washburn  81beec63-eb38-4397-a09d-28ce575f3c50
# 3               Aborted  04f125fa-a6c6-46c1-9237-45ba99b231d6
# 4               Aborted  1225dfae-a116-46b9-ac9e-5ad5bb2ef9f6
# 5               Aborted  3fce030e-3589-496f-a279-8491b010fa88
# 6               Aborted  4cd3b9d5-6a49-469f-afa8-b89e89ee6a74
# 7               Aborted  59356807-86ba-4d19-a1dc-582567cdd7b5
# 8               Aborted  6e24127c-7006-4aa9-897d-64f551c0e0f5
# 9               Aborted  8c111c81-da6a-47a2-b9d1-7f26a1638ec5
# 10              Aborted  8ce9fa08-e558-44ff-86ef-d0d99f5d68fe
# 11              Aborted  93902ab2-f368-4d25-8dc0-cf6b5848f6b3
# 12              Aborted  93902ab2-f368-4d25-8dc0-cf6b5848f6b3
# 13              Aborted  95480217-668c-4fae-8ff6-9530676ea45c
# ...

# %%
import requests
CLIENT_ID = "9a0cd3ac423b43caadb1792ddcc7c8f2"
CLIENT_SECRET = "16ff3ff2eb9b443da33cda187750fa23"

# %%
def _make_http_request(url, method="get", headers=None, params=None, data=None, auth=None):
    """
    Make an HTTP request and return a json object of the response.
    """
    try:
        request_method = requests.post if method == "post" else requests.get
        res = request_method(url, headers=headers, params=params, data=data, auth=auth)
        responsejson = res.json()
        if res.status_code != 200:
            raise Exception(res.text)
    except ValueError:
        # if the response isn't JSON, .json() method will raise JSONDecodeError,
        # which is a subclass of ValueError
        return res.text
    except Exception as err:
        print("Error during HTTP request to {}: {}".format(url, err))
    return responsejson

def request_access_token(client_id, client_secret):
    """
    Request a new access token from Spotify.
    Returns the new access token on success.
    """

    headers = {'Accept': 'application/json'}
    data = [('grant_type', 'client_credentials')]
    res = _make_http_request('https://accounts.spotify.com/api/token', method="post", headers=headers, data=data, auth=(client_id, client_secret))
    try:
        return res['access_token']

    except (KeyError, TypeError):
        print("Error while requesting an access token")

def search_spotify_track(name, access_token):
    """
    Search a track from Spotify.
    Returns first item on success.
    """
    headers = {'Authorization': 'Bearer ' + access_token,}
    params = (('q', name), ('type', 'track'),)
    res = _make_http_request('https://api.spotify.com/v1/search', headers=headers, params=params)
    items = res.get('tracks', {}).get('items', None)
    try:
        return items[0]
    except (IndexError, KeyError):
        return None
def get_audio_features(track_id, access_token):
    """
    Gets audio features of a track from Spotify.
    """
    headers = {'Authorization': 'Bearer ' + access_token,}
    res = _make_http_request('https://api.spotify.com/v1/audio-features/'+ track_id, headers=headers)
    return list(res.values())

FEATURE_SIZE = 18

def get_features_by_query(query, access_token):
    track = search_spotify_track(query, access_token)
    if track != None:
        return get_audio_features(track['id'], access_token)
    else:
        return [0] * FEATURE_SIZE

# %%
query = 'Zakk Wylde Road Back Home'
access_token = request_access_token(CLIENT_ID, CLIENT_SECRET)
track = search_spotify_track(query, access_token)
track
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1AeC9AuzqGc3IXMC2T5xny'},
#     'href': 'https://api.spotify.com/v1/artists/1AeC9AuzqGc3IXMC2T5xny',
#     'id': '1AeC9AuzqGc3IXMC2T5xny',
#     'name': 'Zakk Wylde',
#     'type': 'artist',
#     'uri': 'spotify:artist:1AeC9AuzqGc3IXMC2T5xny'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
# ...

# %%
track['external_urls']
track_id = track['id']

features = get_audio_features(track_id, access_token)
keys = list(features.keys())
print(keys)
list(features.values())
# Out:
# ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature']
# 18

# %%
spotify_features = last_fm_with_msd.head().apply(lambda x: get_features_by_query(x['artist_name'] + ' ' + x['title'], access_token), axis=1)

spotify_features2 = pd.concat({i: get_features_by_query(row['artist_name'] + ' ' + row['title'], access_token) for i, row in last_fm_with_msd.head().iterrows()})
spotify_features2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-e42e0b4600c6> in <module>()
#       1 spotify_features = last_fm_with_msd.head().apply(lambda x: get_features_by_query(x['artist_name'] + ' ' + x['title'], access_token), axis=1)
#       2
# ----> 3 spotify_features2 = pd.concat({i: get_features_by_query(row['artist_name'] + ' ' + row['title'], access_token) for i, row in last_fm_with_msd.head().iterrows()})
#       4 spotify_features2
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# ...
